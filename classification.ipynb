# %% [markdown]
# # KNN Classification
# Perform KNN classification on the dataset `KNNAlgorithmDataset.csv`.

# %%
import pandas as pd
df = pd.read_csv('KNNAlgorithmDataset.csv')
print(df.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
print(df.info())
print("\nMissing values in each column:")
print(df.isnull().sum())

plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), annot=False, cmap='coolwarm', cbar=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# # Bayes Classification
# Perform Bayes classification on the datasets `train_clean.csv` and `test_clean.csv`.

# %%
# Import necessary libraries
from sklearn.naive_bayes import GaussianNB

# Load the datasets
train_data = pd.read_csv('train_clean.csv')
test_data = pd.read_csv('test_clean.csv')

# Preprocess the data (if required)
# Assuming the last column is the target
X_train = train_data.iloc[:, :-1]
y_train = train_data.iloc[:, -1]
X_test = test_data.iloc[:, :-1]
y_test = test_data.iloc[:, -1]

# Train a Naive Bayes classifier
nb = GaussianNB()
nb.fit(X_train, y_train)

# Evaluate the classifier
y_pred = nb.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Naive Bayes Classifier Accuracy: {accuracy:.2f}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12492\740686671.py in ?()
#      14 y_test = test_data.iloc[:, -1]
#      15
#      16 # Train a Naive Bayes classifier
#      17 nb = GaussianNB()
# ---> 18 nb.fit(X_train, y_train)
#      19
#      20 # Evaluate the classifier
#      21 y_pred = nb.predict(X_test)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ...
